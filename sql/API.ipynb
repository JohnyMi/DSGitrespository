# %%
import requests
import json

# %%
url_start = "https://api.openweathermap.org/data/2.5/forecast?q="
url_end = "&appid=ba8fc0c7c0af9f0c2a2e114fc9850623&units=metric"

# %%
mesto = input("Zadaj mesto: ")

# %%
url = url_start + mesto + url_end

# %%
response = requests.get(url)

# %%
json.loads(response.text)
# Out:
# {'cod': '200',
#  'message': 0,
#  'cnt': 40,
#  'list': [{'dt': 1727384400,
#    'main': {'temp': 15.4,
#     'feels_like': 15.45,
#     'temp_min': 15.1,
#     'temp_max': 15.4,
#     'pressure': 1003,
#     'sea_level': 1003,
#     'grnd_level': 969,
#     'humidity': 94,
#     'temp_kf': 0.3},
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10n'}],
#    'clouds': {'all': 20},
#    'wind': {'speed': 4.68, 'deg': 215, 'gust': 11.49},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 3.37},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-09-26 21:00:00'},
#   {'dt': 1727395200,
#    'main': {'temp': 15.45,
#     'feels_like': 15.4,
#     'temp_min': 15.45,
#     'temp_max': 15.56,
#     'pressure': 1003,
#     'sea_level': 1003,
#     'grnd_level': 968,
#     'humidity': 90,
#     'temp_kf': -0.11},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 47},
#    'wind': {'speed': 7.81, 'deg': 227, 'gust': 15.23},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 0.74},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-09-27 00:00:00'},
#   {'dt': 1727406000,
#    'main': {'temp': 14.99,
#     'feels_like': 14.79,
#     'temp_min': 14.79,
#     'temp_max': 14.99,
#     'pressure': 1003,
#     'sea_level': 1003,
#     'grnd_level': 969,
#     'humidity': 86,
#     'temp_kf': 0.2},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 73},
#    'wind': {'speed': 6.35, 'deg': 227, 'gust': 12.38},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-09-27 03:00:00'},
#   {'dt': 1727416800,
#    'main': {'temp': 14.72,
#     'feels_like': 14.34,
#     'temp_min': 14.72,
#     'temp_max': 14.72,
#     'pressure': 1005,
#     'sea_level': 1005,
#     'grnd_level': 971,
#     'humidity': 80,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 5.54, 'deg': 217, 'gust': 10.94},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-09-27 06:00:00'},
#   {'dt': 1727427600,
#    'main': {'temp': 17.79,
#     'feels_like': 17.19,
#     'temp_min': 17.79,
#     'temp_max': 17.79,
#     'pressure': 1005,
#     'sea_level': 1005,
#     'grnd_level': 972,
#     'humidity': 60,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 6, 'deg': 227, 'gust': 9},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-09-27 09:00:00'},
#   {'dt': 1727438400,
#    'main': {'temp': 18.03,
#     'feels_like': 17.43,
#     'temp_min': 18.03,
#     'temp_max': 18.03,
#     'pressure': 1006,
#     'sea_level': 1006,
#     'grnd_level': 972,
#     'humidity': 59,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 99},
#    'wind': {'speed': 6.19, 'deg': 225, 'gust': 8.91},
#    'visibility': 10000,
#    'pop': 0.39,
#    'rain': {'3h': 0.41},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-09-27 12:00:00'},
#   {'dt': 1727449200,
#    'main': {'temp': 16.18,
#     'feels_like': 15.63,
#     'temp_min': 16.18,
#     'temp_max': 16.18,
#     'pressure': 1006,
#     'sea_level': 1006,
#     'grnd_level': 972,
#     'humidity': 68,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 4.39, 'deg': 216, 'gust': 8.49},
#    'visibility': 10000,
#    'pop': 0.98,
#    'rain': {'3h': 0.45},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-09-27 15:00:00'},
#   {'dt': 1727460000,
#    'main': {'temp': 14.18,
#     'feels_like': 13.61,
#     'temp_min': 14.18,
#     'temp_max': 14.18,
#     'pressure': 1008,
#     'sea_level': 1008,
#     'grnd_level': 974,
#     'humidity': 75,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 4.69, 'deg': 218, 'gust': 10.73},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 0.5},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-09-27 18:00:00'},
#   {'dt': 1727470800,
#    'main': {'temp': 12.8,
#     'feels_like': 12.33,
#     'temp_min': 12.8,
#     'temp_max': 12.8,
#     'pressure': 1009,
#     'sea_level': 1009,
#     'grnd_level': 974,
#     'humidity': 84,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 5.73, 'deg': 236, 'gust': 10.96},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 2.2},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-09-27 21:00:00'},
#   {'dt': 1727481600,
#    'main': {'temp': 12.12,
#     'feels_like': 11.45,
#     'temp_min': 12.12,
#     'temp_max': 12.12,
#     'pressure': 1009,
#     'sea_level': 1009,
#     'grnd_level': 975,
#     'humidity': 79,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 4.48, 'deg': 226, 'gust': 10.71},
#    'visibility': 10000,
#    'pop': 0.8,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-09-28 00:00:00'},
#   {'dt': 1727492400,
#    'main': {'temp': 11.07,
#     'feels_like': 10.22,
#     'temp_min': 11.07,
#     'temp_max': 11.07,
#     'pressure': 1010,
#     'sea_level': 1010,
#     'grnd_level': 975,
#     'humidity': 76,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 98},
#    'wind': {'speed': 4.73, 'deg': 208, 'gust': 10.63},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-09-28 03:00:00'},
#   {'dt': 1727503200,
#    'main': {'temp': 11.62,
#     'feels_like': 10.74,
#     'temp_min': 11.62,
#     'temp_max': 11.62,
#     'pressure': 1011,
#     'sea_level': 1011,
#     'grnd_level': 977,
#     'humidity': 73,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 6.35, 'deg': 235, 'gust': 12.35},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-09-28 06:00:00'},
#   {'dt': 1727514000,
#    'main': {'temp': 12.69,
#     'feels_like': 11.97,
#     'temp_min': 12.69,
#     'temp_max': 12.69,
#     'pressure': 1013,
#     'sea_level': 1013,
#     'grnd_level': 979,
#     'humidity': 75,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 94},
#    'wind': {'speed': 7.51, 'deg': 248, 'gust': 10.69},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-09-28 09:00:00'},
#   {'dt': 1727524800,
#    'main': {'temp': 12.1,
#     'feels_like': 11.22,
#     'temp_min': 12.1,
#     'temp_max': 12.1,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 981,
#     'humidity': 71,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 94},
#    'wind': {'speed': 6.48, 'deg': 314, 'gust': 9.16},
#    'visibility': 10000,
#    'pop': 0.2,
#    'rain': {'3h': 0.23},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-09-28 12:00:00'},
#   {'dt': 1727535600,
#    'main': {'temp': 13.44,
#     'feels_like': 12.41,
#     'temp_min': 13.44,
#     'temp_max': 13.44,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 983,
#     'humidity': 60,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 96},
#    'wind': {'speed': 4.98, 'deg': 323, 'gust': 7.82},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-09-28 15:00:00'},
#   {'dt': 1727546400,
#    'main': {'temp': 10.84,
#     'feels_like': 9.65,
#     'temp_min': 10.84,
#     'temp_max': 10.84,
#     'pressure': 1021,
#     'sea_level': 1021,
#     'grnd_level': 987,
#     'humidity': 64,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 98},
#    'wind': {'speed': 3.78, 'deg': 298, 'gust': 8.77},
#    'visibility': 10000,
#    'pop': 0.2,
#    'rain': {'3h': 0.11},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-09-28 18:00:00'},
#   {'dt': 1727557200,
#    'main': {'temp': 8.64,
#     'feels_like': 6.75,
#     'temp_min': 8.64,
#     'temp_max': 8.64,
#     'pressure': 1024,
#     'sea_level': 1024,
#     'grnd_level': 989,
#     'humidity': 76,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.22, 'deg': 300, 'gust': 7.04},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-09-28 21:00:00'},
#   {'dt': 1727568000,
#    'main': {'temp': 7.88,
#     'feels_like': 5.76,
#     'temp_min': 7.88,
#     'temp_max': 7.88,
#     'pressure': 1026,
#     'sea_level': 1026,
#     'grnd_level': 990,
#     'humidity': 77,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.33, 'deg': 293, 'gust': 8.61},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-09-29 00:00:00'},
#   {'dt': 1727578800,
#    'main': {'temp': 7.21,
#     'feels_like': 4.8,
#     'temp_min': 7.21,
#     'temp_max': 7.21,
#     'pressure': 1027,
#     'sea_level': 1027,
#     'grnd_level': 992,
#     'humidity': 78,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.59, 'deg': 298, 'gust': 8.23},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-09-29 03:00:00'},
#   {'dt': 1727589600,
#    'main': {'temp': 6.66,
#     'feels_like': 4.63,
#     'temp_min': 6.66,
#     'temp_max': 6.66,
#     'pressure': 1029,
#     'sea_level': 1029,
#     'grnd_level': 993,
#     'humidity': 81,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 96},
#    'wind': {'speed': 2.82, 'deg': 303, 'gust': 6.67},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-09-29 06:00:00'},
#   {'dt': 1727600400,
#    'main': {'temp': 10.91,
#     'feels_like': 9.54,
#     'temp_min': 10.91,
#     'temp_max': 10.91,
#     'pressure': 1030,
#     'sea_level': 1030,
#     'grnd_level': 994,
#     'humidity': 57,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 9},
#    'wind': {'speed': 3.64, 'deg': 339, 'gust': 5.06},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-09-29 09:00:00'},
#   {'dt': 1727611200,
#    'main': {'temp': 11.93,
#     'feels_like': 10.48,
#     'temp_min': 11.93,
#     'temp_max': 11.93,
#     'pressure': 1029,
#     'sea_level': 1029,
#     'grnd_level': 994,
#     'humidity': 50,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 48},
#    'wind': {'speed': 3.1, 'deg': 346, 'gust': 4.33},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-09-29 12:00:00'},
#   {'dt': 1727622000,
#    'main': {'temp': 12.02,
#     'feels_like': 10.58,
#     'temp_min': 12.02,
#     'temp_max': 12.02,
#     'pressure': 1028,
#     'sea_level': 1028,
#     'grnd_level': 993,
#     'humidity': 50,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 92},
#    'wind': {'speed': 2.83, 'deg': 12, 'gust': 3.65},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-09-29 15:00:00'},
#   {'dt': 1727632800,
#    'main': {'temp': 9.86,
#     'feels_like': 9.13,
#     'temp_min': 9.86,
#     'temp_max': 9.86,
#     'pressure': 1030,
#     'sea_level': 1030,
#     'grnd_level': 994,
#     'humidity': 55,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 85},
#    'wind': {'speed': 1.88, 'deg': 66, 'gust': 2.69},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-09-29 18:00:00'},
#   {'dt': 1727643600,
#    'main': {'temp': 9.52,
#     'feels_like': 9.26,
#     'temp_min': 9.52,
#     'temp_max': 9.52,
#     'pressure': 1030,
#     'sea_level': 1030,
#     'grnd_level': 995,
#     'humidity': 55,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 75},
#    'wind': {'speed': 1.36, 'deg': 108, 'gust': 2.68},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-09-29 21:00:00'},
#   {'dt': 1727654400,
#    'main': {'temp': 6.29,
#     'feels_like': 5.01,
#     'temp_min': 6.29,
#     'temp_max': 6.29,
#     'pressure': 1030,
#     'sea_level': 1030,
#     'grnd_level': 994,
#     'humidity': 69,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 51},
#    'wind': {'speed': 1.86, 'deg': 141, 'gust': 2.77},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-09-30 00:00:00'},
#   {'dt': 1727665200,
#    'main': {'temp': 5.46,
#     'feels_like': 4.32,
#     'temp_min': 5.46,
#     'temp_max': 5.46,
#     'pressure': 1029,
#     'sea_level': 1029,
#     'grnd_level': 993,
#     'humidity': 72,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 9},
#    'wind': {'speed': 1.62, 'deg': 130, 'gust': 2.28},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-09-30 03:00:00'},
#   {'dt': 1727676000,
#    'main': {'temp': 5.68,
#     'feels_like': 4.49,
#     'temp_min': 5.68,
#     'temp_max': 5.68,
#     'pressure': 1028,
#     'sea_level': 1028,
#     'grnd_level': 992,
#     'humidity': 71,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 9},
#    'wind': {'speed': 1.69, 'deg': 132, 'gust': 2.99},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-09-30 06:00:00'},
#   {'dt': 1727686800,
#    'main': {'temp': 11.05,
#     'feels_like': 9.52,
#     'temp_min': 11.05,
#     'temp_max': 11.05,
#     'pressure': 1026,
#     'sea_level': 1026,
#     'grnd_level': 991,
#     'humidity': 50,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 92},
#    'wind': {'speed': 5.03, 'deg': 147, 'gust': 7.78},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-09-30 09:00:00'},
#   {'dt': 1727697600,
#    'main': {'temp': 13.87,
#     'feels_like': 12.44,
#     'temp_min': 13.87,
#     'temp_max': 13.87,
#     'pressure': 1023,
#     'sea_level': 1023,
#     'grnd_level': 988,
#     'humidity': 43,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 96},
#    'wind': {'speed': 5.66, 'deg': 155, 'gust': 7.25},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-09-30 12:00:00'},
#   {'dt': 1727708400,
#    'main': {'temp': 14.37,
#     'feels_like': 13.12,
#     'temp_min': 14.37,
#     'temp_max': 14.37,
#     'pressure': 1021,
#     'sea_level': 1021,
#     'grnd_level': 986,
#     'humidity': 48,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 56},
#    'wind': {'speed': 4.22, 'deg': 163, 'gust': 5.65},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-09-30 15:00:00'},
#   {'dt': 1727719200,
#    'main': {'temp': 10.14,
#     'feels_like': 8.88,
#     'temp_min': 10.14,
#     'temp_max': 10.14,
#     'pressure': 1020,
#     'sea_level': 1020,
#     'grnd_level': 985,
#     'humidity': 64,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 58},
#    'wind': {'speed': 2.81, 'deg': 156, 'gust': 5.04},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-09-30 18:00:00'},
#   {'dt': 1727730000,
#    'main': {'temp': 11.06,
#     'feels_like': 9.81,
#     'temp_min': 11.06,
#     'temp_max': 11.06,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 983,
#     'humidity': 61,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 93},
#    'wind': {'speed': 2.21, 'deg': 165, 'gust': 4.36},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-09-30 21:00:00'},
#   {'dt': 1727740800,
#    'main': {'temp': 10.92,
#     'feels_like': 9.74,
#     'temp_min': 10.92,
#     'temp_max': 10.92,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 983,
#     'humidity': 64,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 97},
#    'wind': {'speed': 2.1, 'deg': 193, 'gust': 3.52},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-10-01 00:00:00'},
#   {'dt': 1727751600,
#    'main': {'temp': 11.04,
#     'feels_like': 10.05,
#     'temp_min': 11.04,
#     'temp_max': 11.04,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 981,
#     'humidity': 71,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 2.32, 'deg': 195, 'gust': 5.75},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-10-01 03:00:00'},
#   {'dt': 1727762400,
#    'main': {'temp': 10.4,
#     'feels_like': 9.61,
#     'temp_min': 10.4,
#     'temp_max': 10.4,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 980,
#     'humidity': 81,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 1.66, 'deg': 164, 'gust': 1.69},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-10-01 06:00:00'},
#   {'dt': 1727773200,
#    'main': {'temp': 11.27,
#     'feels_like': 10.75,
#     'temp_min': 11.27,
#     'temp_max': 11.27,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 979,
#     'humidity': 88,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 2.35, 'deg': 147, 'gust': 3.57},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 1.08},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-10-01 09:00:00'},
#   {'dt': 1727784000,
#    'main': {'temp': 15.35,
#     'feels_like': 14.79,
#     'temp_min': 15.35,
#     'temp_max': 15.35,
#     'pressure': 1012,
#     'sea_level': 1012,
#     'grnd_level': 978,
#     'humidity': 71,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 4.94, 'deg': 175, 'gust': 8.87},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 0.12},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-10-01 12:00:00'},
#   {'dt': 1727794800,
#    'main': {'temp': 13.45,
#     'feels_like': 13.12,
#     'temp_min': 13.45,
#     'temp_max': 13.45,
#     'pressure': 1011,
#     'sea_level': 1011,
#     'grnd_level': 977,
#     'humidity': 87,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 4.15, 'deg': 190, 'gust': 10.76},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 0.63},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-10-01 15:00:00'},
#   {'dt': 1727805600,
#    'main': {'temp': 13.01,
#     'feels_like': 12.59,
#     'temp_min': 13.01,
#     'temp_max': 13.01,
#     'pressure': 1012,
#     'sea_level': 1012,
#     'grnd_level': 978,
#     'humidity': 85,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.39, 'deg': 229, 'gust': 6.88},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 0.78},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-10-01 18:00:00'}],
#  'city': {'id': 3067696,
#   'name': 'Prague',
#   'coord': {'lat': 50.088, 'lon': 14.4208},
#   'country': 'CZ',
#   'population': 1165581,
#   'timezone': 7200,
#   'sunrise': 1727326501,
#   'sunset': 1727369523}}
